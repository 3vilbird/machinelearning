# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df =pd.read_csv('C:/Users/Black_devil/advancedpandas/intel.csv')
x1=df.Open
y1=df.Close
plt.plot(x1, y1, label = "line 2")
plt.show()
df
objects = ('Date','Open','High','Low','close')
y_pos = np.arange(len(objects))

popularity=[[df.Date],[df.Open],[df.High],[df.Low],[df.Close] ]

plt.bar(y_pos, popularity, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title(' languages')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-7555838e6c2c> in <module>()
#      13 popularity=[[df.Date],[df.Open],[df.High],[df.Low],[df.Close] ]
#      14
# ---> 15 plt.bar(y_pos, popularity, align='center', alpha=0.5)
#      16 plt.xticks(y_pos, objects)
#      17 plt.ylabel('Usage')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2768                       mplDeprecation)
#    2769     try:
# -> 2770         ret = ax.bar(*args, **kwargs)
#    2771     finally:
#    2772         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def sinplot( flip =1):
    x = np.linspace(0,14,100)
    for  i in range(1,3):
        plt.plot(x,np.sin(x+i*.5)*(7- i )*flip)

        
        
sns.set_style('dark') # adding style to back ground
sns.set(data=dat)
sinplot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c1255f5e5a4a> in <module>()
#       9
#      10 sns.set_style('dark') # adding style to back ground
# ---> 11 sns.set(data=dat)
#      12 sinplot()
#
# NameError: name 'dat' is not defined

# %%
# box plot
data = np.random.normal(size=(20,6))+np.arange(6)/2
sns.set_style("whitegrid")
sns.boxplot(data=data)
'''A box plot consist of 5 things.

    Minimum
    First Quartile or 25%
    Median (Second Quartile) or 50%
    Third Quartile or 75%
    Maximum



'''

# %%
f , ax = plt.subplots()
sns.violinplot(data=data)

# %%
sns.set_context("paper")
sinplot()

# %%
sns.set_context("talk")
sinplot()

# %%
sns.palplot( sns.color_palette())

# %%
sns.palplot( sns.color_palette("muted"))

# %%
sns.palplot( sns.color_palette("RdBu",n_colors=9))

# %%
sns.palplot( sns.color_palette("Blues_d"))

# %%
lol=[ '#DEB887','#DEB887 ','#DEB887','#ff4d4d','#4dff4d','#004d3d'  ]
sns.palplot( sns.color_palette(lol))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     165     try:
# --> 166         rgba = _colors_full_map.cache[c, alpha]
#     167     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: ('#DEB887 ', None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\seaborn\palettes.py in color_palette(palette, n_colors, desat)
#     190         palette = map(mpl.colors.colorConverter.to_rgb, palette)
# --> 191         palette = _ColorPalette(palette)
#     192     except ValueError:
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgb(arg)
#     327         """
# --> 328         return to_rgb(arg)
#     329
#
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np
df = pd.DataFrame(dict(time=np.arange(500),value=np.random.randn(500).cumsum()))

# %%
g=sns.relplot(x='time',y='value',kind='line',data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-25042ba851ff> in <module>()
# ----> 1 g=sns.relplot(x='time',y='value',kind='line',data=df)
#
# AttributeError: module 'seaborn' has no attribute 'relplot'
