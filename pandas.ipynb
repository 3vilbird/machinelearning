# %%
'''
pandas :
rows == series
colomns ==data frames
2d array
import pandas as ppppppppppppppppp

'''
import pandas as pd
import numpy as np 

d= {'name':["dog","cat"],'age':["3","4"],'name':["dog","cat"],'age':["3","4"]   }
#print(d)
pd.DataFrame(data=d)
# Out:
#   name age
# 0  dog   3
# 1  cat   4

# %%
raw_data = {'name': ['Willard Morris', 'Al Jennings', 'Omar Mullins', 'Spencer McDaniel'],
'age': [20, 19, 22, 21],
'favorite_color': ['blue', 'red', 'yellow', "green"],
'grade': [88, 92, 95, 70],
'birth_date': ['01-02-1996', '08-05-1997', '04-28-1996', '12-16-1995']}
df = pd.DataFrame(raw_data, index = ['Willard Morris', 'Al Jennings', 'Omar Mullins', 'Spencer McDaniel'])
df
# Out:
#                               name  age favorite_color  grade  birth_date
# Willard Morris      Willard Morris   20           blue     88  01-02-1996
# Al Jennings            Al Jennings   19            red     92  08-05-1997
# Omar Mullins          Omar Mullins   22         yellow     95  04-28-1996
# Spencer McDaniel  Spencer McDaniel   21          green     70  12-16-1995

# %%
raw_data = {'name': ['Willard Morris', 'Al Jennings', 'Omar Mullins', 'Spencer McDaniel'],
'age': [20, 19, 22, 21],
'favorite_color': ['blue', 'red', 'yellow', "green"],
'grade': [88, 92, 95, 70],
'birth_date': ['01-02-1996', '08-05-1997', '04-28-1996', '12-16-1995']}
df = pd.DataFrame(data=raw_data)
dd= pd.DataFrame(raw_data, index = ['Willard Morris', 'Al Jennings', 'Omar Mullins', 'Spencer McDaniel'])
df
# Out:
#                name  age favorite_color  grade  birth_date
# 0    Willard Morris   20           blue     88  01-02-1996
# 1       Al Jennings   19            red     92  08-05-1997
# 2      Omar Mullins   22         yellow     95  04-28-1996
# 3  Spencer McDaniel   21          green     70  12-16-1995

# %%
lol=pd.concat([df,dd])
lol
# Out:
#                               name  age favorite_color  grade  birth_date
# Willard Morris      Willard Morris   20           blue     88  01-02-1996
# Al Jennings            Al Jennings   19            red     92  08-05-1997
# Omar Mullins          Omar Mullins   22         yellow     95  04-28-1996
# Spencer McDaniel  Spencer McDaniel   21          green     70  12-16-1995
# Willard Morris      Willard Morris   20           blue     88  01-02-1996
# Al Jennings            Al Jennings   19            red     92  08-05-1997
# Omar Mullins          Omar Mullins   22         yellow     95  04-28-1996
# Spencer McDaniel  Spencer McDaniel   21          green     70  12-16-1995
